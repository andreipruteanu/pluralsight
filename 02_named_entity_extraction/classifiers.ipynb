# %%
import pandas as pd
import numpy as np
import scipy.stats
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MultiLabelBinarizer

import matplotlib.pyplot as plt

import sklearn_crfsuite
from sklearn_crfsuite import metrics
from collections import Counter

import eli5

from pprint import pprint
from spacy import displacy
from collections import Counter
import en_core_web_sm

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# dataset taken from: https://www.kaggle.com/abhinavwalia95/entity-annotated-corpus/version/4#ner_dataset.csv
raw_data = pd.read_csv('ner_dataset.csv', encoding = "ISO-8859-1")

# "Tag" column uses:
#   1) IOB-2 format:
#     I: word is inside of a chunk
#     O: word is outside of a chunk
#     B: word is at tge beginning of a chunk
#     S: word is a single-word chunk
#     E: word is at end of chunk word
#   2) Entities:
#     geo: Geographical Entity
#     org: Organization
#     per: Person
#     gpe: Geopolitical Entity
#     tim: Time indicator
#     art: Artifact
#     eve: Event
#     nat: Natural Phenomenon
# "POS" column uses POS (Part of Speech Tagging)

# use a subset of the data due to memory constraints
raw_data = raw_data[:30000]

# %%
# fill NaNs
data = raw_data.fillna(method='ffill')

# %%
# create "x" of training data by removing the "y" column ("Tag") from the dataset
x = data.drop('Tag', axis=1)

# print(x)

# DictVectorizer transformer turns lists of mappings (dict-like objects) of feature names 
# to feature values into Numpy arrays or scipy.sparse matrices for use with 
# scikit-learn estimators.
dv = DictVectorizer(sparse=False)
x = dv.fit_transform(x.to_dict('records'))

# create training data "y"
y = data.Tag.values

# select "classes"
classes = np.unique(y).tolist()

# %%
# spliting dataset into train and test
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

classes_without_o = list(set(y_train) - {'O'})

# classification accuracy report
cr = dict()

# %%
# %%time
# Stochastic Gradient Descent
from sklearn.linear_model import SGDClassifier

model_sgd = SGDClassifier()
model_sgd.partial_fit(x_train, y_train, classes)
# Out:
# CPU times: user 4.05 s, sys: 0 ns, total: 4.05 s
# Wall time: 4.05 s
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
from sklearn.metrics import classification_report

report = classification_report(y_pred=model_sgd.predict(x_test), y_true=y_test, labels=classes_without_o, output_dict=True)
cr['sgd'] = report['weighted avg']
# Out:
# /home/andrei/work/repos/datascience/venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %%time
# Naive Bayes
from sklearn.naive_bayes import MultinomialNB

model_nb = MultinomialNB()
model_nb.partial_fit(x_train, y_train, classes)
# Out:
# CPU times: user 1.85 s, sys: 419 ms, total: 2.27 s
# Wall time: 488 ms
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
report = classification_report(y_pred=model_nb.predict(x_test), y_true=y_test, labels=classes_without_o, output_dict=True)
cr['nb'] = report['weighted avg']
# Out:
# /home/andrei/work/repos/datascience/venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %%time
# Logistic Regression
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(n_jobs=-1)
model_lr.fit(x_train, y_train)
# Out:
# CPU times: user 246 ms, sys: 647 ms, total: 893 ms
# Wall time: 2min 17s
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=-1, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
report = classification_report(y_pred=model_lr.predict(x_test), y_true=y_test, labels=classes_without_o, output_dict=True)
cr['lr'] = report['weighted avg']
# Out:
# /home/andrei/work/repos/datascience/venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %%time
# Support Vector Classifier
from sklearn import svm

model_svc = svm.SVC()
model_svc.fit(x_train, y_train)
# Out:
# CPU times: user 1h 41s, sys: 1.42 s, total: 1h 43s
# Wall time: 1h 43s
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
report = classification_report(y_pred=model_svc.predict(x_test), y_true=y_test, labels=classes_without_o, output_dict=True)
cr['svc'] = report['weighted avg']
# Out:
# /home/andrei/work/repos/datascience/venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier()
model_dt.fit(x_train, y_train)
# Out:
# CPU times: user 1min 54s, sys: 68 ms, total: 1min 54s
# Wall time: 1min 54s
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
report = classification_report(y_pred=model_dt.predict(x_test), y_true=y_test, labels=classes_without_o, output_dict=True)
cr['dt'] = report['weighted avg']

# %%
# model training time
time_df = pd.DataFrame.from_dict({'nb': 0.397, 'svc': 3480, 'dt': 101, 'lr': 121, 'sgd': 4}, orient='index')
time_df.plot(kind='bar', grid=True, figsize=(16,4), title='Training Time')

# %%
# model accuracy
cr_df = pd.DataFrame.from_dict(cr, orient='index')

# %%
cr_df['precision'].plot(kind='bar', grid=True, figsize=(16,4), title='Precision')

# %%
cr_df['recall'].plot(kind='bar', grid=True, figsize=(16,4), title='Recall')

# %%
cr_df['f1-score'].plot(kind='bar', grid=True, figsize=(16,4), title='F1')

# %%
# compute % difference to the best
cr_df_perc = pd.DataFrame(columns=['precision', 'recall', 'f1-score', 'support'])
cr_df_perc.loc['nb'] = (cr_df.loc['nb'] - cr_df.loc['dt']) / cr_df.loc['dt'] * 100
cr_df_perc.loc['sgd'] = (cr_df.loc['sgd'] - cr_df.loc['dt']) / cr_df.loc['dt'] * 100
cr_df_perc.loc['svc'] = (cr_df.loc['svc'] - cr_df.loc['dt']) / cr_df.loc['dt'] * 100
cr_df_perc.loc['lr'] = (cr_df.loc['lr'] - cr_df.loc['dt']) / cr_df.loc['dt'] * 100
cr_df_perc.loc['dt'] = (cr_df.loc['dt'] - cr_df.loc['dt']) / cr_df.loc['dt'] * 100

# %%
# plot % differences
cr_df_perc['precision'].plot(kind='bar', grid=True, figsize=(16, 4), title='Precision % difference')

# %%
cr_df_perc['recall'].plot(kind='bar', grid=True, figsize=(16, 4), title='Recall % difference')

# %%
cr_df_perc['f1-score'].plot(kind='bar', grid=True, figsize=(16, 4), title='F1 % difference')

# %%
# Conditional Random Fields

# create sentences
def create_sentences(data):
    agg_func = lambda s: [(w, p, t) for w, p, t in zip(s['Word'].values.tolist(),
                                                      s['POS'].values.tolist(),
                                                      s['Tag'].values.tolist())]
    grouped = data.groupby('Sentence #').apply(agg_func)
    sentences = [s for s in grouped]
    return sentences

# create CRF input sentences
sentences = create_sentences(data)

# %%
print(sentences[0])
# Out:
# [('Thousands', 'NNS', 'O'), ('of', 'IN', 'O'), ('demonstrators', 'NNS', 'O'), ('have', 'VBP', 'O'), ('marched', 'VBN', 'O'), ('through', 'IN', 'O'), ('London', 'NNP', 'B-geo'), ('to', 'TO', 'O'), ('protest', 'VB', 'O'), ('the', 'DT', 'O'), ('war', 'NN', 'O'), ('in', 'IN', 'O'), ('Iraq', 'NNP', 'B-geo'), ('and', 'CC', 'O'), ('demand', 'VB', 'O'), ('the', 'DT', 'O'), ('withdrawal', 'NN', 'O'), ('of', 'IN', 'O'), ('British', 'JJ', 'B-gpe'), ('troops', 'NNS', 'O'), ('from', 'IN', 'O'), ('that', 'DT', 'O'), ('country', 'NN', 'O'), ('.', '.', 'O')]

# %%
# feature extraction
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True
    
    return features

def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

# %%
# create input and output training data
x = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# 1st sentence - text format
sentence_txt = ' '.join([it[0] for it in sentences[0]]) + '\n'
print(sentence_txt)
# Out:
# Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .

# %%
# 1st sentence - tuples and features
for s_item, x_item in zip(sentences[0], x[0]):
    print('sentence item: {}'.format(s_item))
    print('x_item: {}\n'.format(x_item))
# Out:
# sentence item: ('Thousands', 'NNS', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'thousands', 'word[-3:]': 'nds', 'word[-2:]': 'ds', 'word.isupper()': False, 'word.istitle()': True, 'word.isdigit()': False, 'postag': 'NNS', 'postag[:2]': 'NN', 'BOS': True, '+1:word.lower()': 'of', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'IN', '+1:postag[:2]': 'IN'}
#
# sentence item: ('of', 'IN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'of', 'word[-3:]': 'of', 'word[-2:]': 'of', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'IN', 'postag[:2]': 'IN', '-1:word.lower()': 'thousands', '-1:word.istitle()': True, '-1:word.isupper()': False, '-1:postag': 'NNS', '-1:postag[:2]': 'NN', '+1:word.lower()': 'demonstrators', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'NNS', '+1:postag[:2]': 'NN'}
#
# sentence item: ('demonstrators', 'NNS', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'demonstrators', 'word[-3:]': 'ors', 'word[-2:]': 'rs', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'NNS', 'postag[:2]': 'NN', '-1:word.lower()': 'of', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'IN', '-1:postag[:2]': 'IN', '+1:word.lower()': 'have', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'VBP', '+1:postag[:2]': 'VB'}
#
# sentence item: ('have', 'VBP', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'have', 'word[-3:]': 'ave', 'word[-2:]': 've', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'VBP', 'postag[:2]': 'VB', '-1:word.lower()': 'demonstrators', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'NNS', '-1:postag[:2]': 'NN', '+1:word.lower()': 'marched', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'VBN', '+1:postag[:2]': 'VB'}
#
# sentence item: ('marched', 'VBN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'marched', 'word[-3:]': 'hed', 'word[-2:]': 'ed', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'VBN', 'postag[:2]': 'VB', '-1:word.lower()': 'have', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'VBP', '-1:postag[:2]': 'VB', '+1:word.lower()': 'through', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'IN', '+1:postag[:2]': 'IN'}
#
# sentence item: ('through', 'IN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'through', 'word[-3:]': 'ugh', 'word[-2:]': 'gh', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'IN', 'postag[:2]': 'IN', '-1:word.lower()': 'marched', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'VBN', '-1:postag[:2]': 'VB', '+1:word.lower()': 'london', '+1:word.istitle()': True, '+1:word.isupper()': False, '+1:postag': 'NNP', '+1:postag[:2]': 'NN'}
#
# sentence item: ('London', 'NNP', 'B-geo')
# x_item: {'bias': 1.0, 'word.lower()': 'london', 'word[-3:]': 'don', 'word[-2:]': 'on', 'word.isupper()': False, 'word.istitle()': True, 'word.isdigit()': False, 'postag': 'NNP', 'postag[:2]': 'NN', '-1:word.lower()': 'through', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'IN', '-1:postag[:2]': 'IN', '+1:word.lower()': 'to', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'TO', '+1:postag[:2]': 'TO'}
#
# sentence item: ('to', 'TO', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'to', 'word[-3:]': 'to', 'word[-2:]': 'to', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'TO', 'postag[:2]': 'TO', '-1:word.lower()': 'london', '-1:word.istitle()': True, '-1:word.isupper()': False, '-1:postag': 'NNP', '-1:postag[:2]': 'NN', '+1:word.lower()': 'protest', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'VB', '+1:postag[:2]': 'VB'}
#
# sentence item: ('protest', 'VB', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'protest', 'word[-3:]': 'est', 'word[-2:]': 'st', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'VB', 'postag[:2]': 'VB', '-1:word.lower()': 'to', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'TO', '-1:postag[:2]': 'TO', '+1:word.lower()': 'the', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'DT', '+1:postag[:2]': 'DT'}
#
# sentence item: ('the', 'DT', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'the', 'word[-3:]': 'the', 'word[-2:]': 'he', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'DT', 'postag[:2]': 'DT', '-1:word.lower()': 'protest', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'VB', '-1:postag[:2]': 'VB', '+1:word.lower()': 'war', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'NN', '+1:postag[:2]': 'NN'}
#
# sentence item: ('war', 'NN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'war', 'word[-3:]': 'war', 'word[-2:]': 'ar', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'NN', 'postag[:2]': 'NN', '-1:word.lower()': 'the', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'DT', '-1:postag[:2]': 'DT', '+1:word.lower()': 'in', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'IN', '+1:postag[:2]': 'IN'}
#
# sentence item: ('in', 'IN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'in', 'word[-3:]': 'in', 'word[-2:]': 'in', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'IN', 'postag[:2]': 'IN', '-1:word.lower()': 'war', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'NN', '-1:postag[:2]': 'NN', '+1:word.lower()': 'iraq', '+1:word.istitle()': True, '+1:word.isupper()': False, '+1:postag': 'NNP', '+1:postag[:2]': 'NN'}
#
# sentence item: ('Iraq', 'NNP', 'B-geo')
# x_item: {'bias': 1.0, 'word.lower()': 'iraq', 'word[-3:]': 'raq', 'word[-2:]': 'aq', 'word.isupper()': False, 'word.istitle()': True, 'word.isdigit()': False, 'postag': 'NNP', 'postag[:2]': 'NN', '-1:word.lower()': 'in', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'IN', '-1:postag[:2]': 'IN', '+1:word.lower()': 'and', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'CC', '+1:postag[:2]': 'CC'}
#
# sentence item: ('and', 'CC', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'and', 'word[-3:]': 'and', 'word[-2:]': 'nd', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'CC', 'postag[:2]': 'CC', '-1:word.lower()': 'iraq', '-1:word.istitle()': True, '-1:word.isupper()': False, '-1:postag': 'NNP', '-1:postag[:2]': 'NN', '+1:word.lower()': 'demand', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'VB', '+1:postag[:2]': 'VB'}
#
# sentence item: ('demand', 'VB', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'demand', 'word[-3:]': 'and', 'word[-2:]': 'nd', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'VB', 'postag[:2]': 'VB', '-1:word.lower()': 'and', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'CC', '-1:postag[:2]': 'CC', '+1:word.lower()': 'the', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'DT', '+1:postag[:2]': 'DT'}
#
# sentence item: ('the', 'DT', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'the', 'word[-3:]': 'the', 'word[-2:]': 'he', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'DT', 'postag[:2]': 'DT', '-1:word.lower()': 'demand', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'VB', '-1:postag[:2]': 'VB', '+1:word.lower()': 'withdrawal', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'NN', '+1:postag[:2]': 'NN'}
#
# sentence item: ('withdrawal', 'NN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'withdrawal', 'word[-3:]': 'wal', 'word[-2:]': 'al', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'NN', 'postag[:2]': 'NN', '-1:word.lower()': 'the', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'DT', '-1:postag[:2]': 'DT', '+1:word.lower()': 'of', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'IN', '+1:postag[:2]': 'IN'}
#
# sentence item: ('of', 'IN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'of', 'word[-3:]': 'of', 'word[-2:]': 'of', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'IN', 'postag[:2]': 'IN', '-1:word.lower()': 'withdrawal', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'NN', '-1:postag[:2]': 'NN', '+1:word.lower()': 'british', '+1:word.istitle()': True, '+1:word.isupper()': False, '+1:postag': 'JJ', '+1:postag[:2]': 'JJ'}
#
# sentence item: ('British', 'JJ', 'B-gpe')
# x_item: {'bias': 1.0, 'word.lower()': 'british', 'word[-3:]': 'ish', 'word[-2:]': 'sh', 'word.isupper()': False, 'word.istitle()': True, 'word.isdigit()': False, 'postag': 'JJ', 'postag[:2]': 'JJ', '-1:word.lower()': 'of', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'IN', '-1:postag[:2]': 'IN', '+1:word.lower()': 'troops', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'NNS', '+1:postag[:2]': 'NN'}
#
# sentence item: ('troops', 'NNS', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'troops', 'word[-3:]': 'ops', 'word[-2:]': 'ps', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'NNS', 'postag[:2]': 'NN', '-1:word.lower()': 'british', '-1:word.istitle()': True, '-1:word.isupper()': False, '-1:postag': 'JJ', '-1:postag[:2]': 'JJ', '+1:word.lower()': 'from', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'IN', '+1:postag[:2]': 'IN'}
#
# sentence item: ('from', 'IN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'from', 'word[-3:]': 'rom', 'word[-2:]': 'om', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'IN', 'postag[:2]': 'IN', '-1:word.lower()': 'troops', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'NNS', '-1:postag[:2]': 'NN', '+1:word.lower()': 'that', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'DT', '+1:postag[:2]': 'DT'}
#
# sentence item: ('that', 'DT', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'that', 'word[-3:]': 'hat', 'word[-2:]': 'at', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'DT', 'postag[:2]': 'DT', '-1:word.lower()': 'from', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'IN', '-1:postag[:2]': 'IN', '+1:word.lower()': 'country', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': 'NN', '+1:postag[:2]': 'NN'}
#
# sentence item: ('country', 'NN', 'O')
# x_item: {'bias': 1.0, 'word.lower()': 'country', 'word[-3:]': 'try', 'word[-2:]': 'ry', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': 'NN', 'postag[:2]': 'NN', '-1:word.lower()': 'that', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'DT', '-1:postag[:2]': 'DT', '+1:word.lower()': '.', '+1:word.istitle()': False, '+1:word.isupper()': False, '+1:postag': '.', '+1:postag[:2]': '.'}
#
# sentence item: ('.', '.', 'O')
# x_item: {'bias': 1.0, 'word.lower()': '.', 'word[-3:]': '.', 'word[-2:]': '.', 'word.isupper()': False, 'word.istitle()': False, 'word.isdigit()': False, 'postag': '.', 'postag[:2]': '.', '-1:word.lower()': 'country', '-1:word.istitle()': False, '-1:word.isupper()': False, '-1:postag': 'NN', '-1:postag[:2]': 'NN', 'EOS': True}

# %%
# %%time
# train dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

# train default CRF model
model_crf = sklearn_crfsuite.CRF(algorithm='lbfgs', all_possible_transitions=True)
model_crf.fit(x_train, y_train)

# compute y_pred
y_pred = model_crf.predict(x_test)
# Out:
# CPU times: user 8.01 s, sys: 12 ms, total: 8.02 s
# Wall time: 8.02 s

# %%
y_pred
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe',
#   'O',
#   'B-gpe',
#   'I-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'B-tim',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O'],
#  ['O', 'B-org', 'I-org', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'O',
#   'B-gpe',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'I-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'B-gpe',
#   'O',
#   'O',
#   'B-geo',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O'],
#  ['O',
#   'B-per',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O'],
#  ['O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'B-per',
#   'I-per',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'I-geo',
#   'I-geo',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O'],
#  ['B-gpe',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'I-gpe',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-per', 'I-per', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-org', 'B-tim', 'O', 'O', 'O', 'O', 'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'O',
#   'B-gpe',
#   'I-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-nat',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'B-gpe',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-geo',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'B-geo', 'I-geo', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'B-geo',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-geo',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-art',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'B-geo',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O'],
#  ['B-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-gpe', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O'],
#  ['B-per',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-tim', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'I-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'B-per',
#   'I-per',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-art',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'B-tim',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-per',
#   'I-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-gpe',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-gpe',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'B-gpe',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-tim', 'I-tim', 'I-tim', 'O'],
#  ['O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'B-geo',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O'],
#  ['B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-tim',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'B-geo', 'O', 'O', 'O', 'B-eve', 'O'],
#  ['O',
#   'B-geo',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'B-art',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'B-gpe',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'B-gpe',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'B-gpe',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-org', 'I-org', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'B-org', 'I-org', 'O', 'O', 'O', 'O', 'O'],
#  ['B-geo', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O',
#   'O'],
#  ['B-gpe',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'B-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O'],
#  ['B-org',
#   'I-org',
#   'I-org',
#   'B-per',
#   'I-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-per',
#   'I-per',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-per',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'I-tim',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O'],
#  ['B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-org',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'I-geo',
#   'O'],
#  ['O',
#   'B-org',
#   'I-org',
#   'I-org',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'B-gpe',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O'],
#  ['O',
#   'B-gpe',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-geo',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-gpe',
#   'O',
#   'O',
#   'B-tim',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-per',
#   'I-per',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']]

# %%
# compute classification report
report = metrics.flat_classification_report(y_pred=y_pred, y_true=y_test, labels=classes_without_o, output_dict=True)

# add CRF scores to overall classification report
cr['crf'] = report['weighted avg']

# convert classification report to Pandas dataframe
report_df = pd.DataFrame.from_dict(report, orient='index')

report_df[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(16, 4), grid=True)
# Out:
# /home/andrei/work/repos/datascience/venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# convert overall classification report to Pandas DataFrame
cr_df = pd.DataFrame.from_dict(cr, orient='index')

# compute % delta difference to CRF
cr_df_delta = pd.DataFrame(columns=['precision', 'recall', 'f1-score'])
cr_df_delta.loc['sgd'] = (cr_df.loc['sgd'] - cr_df.loc['crf']) / cr_df.loc['crf'] * 100
cr_df_delta.loc['nb'] = (cr_df.loc['nb'] - cr_df.loc['crf']) / cr_df.loc['crf'] * 100
cr_df_delta.loc['lr'] = (cr_df.loc['lr'] - cr_df.loc['crf']) / cr_df.loc['crf'] * 100
cr_df_delta.loc['svc'] = (cr_df.loc['svc'] - cr_df.loc['crf']) / cr_df.loc['crf'] * 100
cr_df_delta.loc['dt'] = (cr_df.loc['dt'] - cr_df.loc['crf']) / cr_df.loc['crf'] * 100
cr_df_delta.loc['crf'] = (cr_df.loc['crf'] - cr_df.loc['crf']) / cr_df.loc['crf'] * 100

# %%
# plot absolute performance
cr_df[['precision', 'recall', 'f1-score']].plot(kind='bar', grid=True, figsize=(16,4), title='Absolute Performance')

# %%
# plot performance delta
cr_df_delta.plot(kind='bar', grid=True, figsize=(16, 4), title='Performance Delta to CRF [%]')

# %%
# model training time
time_data = {'nb': 0.397, 'svc': 3480, 'dt': 101, 'lr': 121, 'sgd': 4, 'crf': 4.9}
time_df = pd.DataFrame.from_dict(time_data, orient='index')

# rename default column name - 0 - to 'training time'
time_df = time_df.rename(columns={0: 'Training Time [sec]'})

# %%
# plot training time
time_df.plot(kind='bar', grid=True, figsize=(16, 4), title='Training Time')

# %%
def compute_algorithm_efficiency(time_data, threshold):
    # initialize performance dictionary
    performance_per_time = {}

    # compute performance per time
    for k, v in time_data.items():
        if cr[k]['f1-score'] >= threshold:
            performance_per_time[k] = cr[k]['f1-score'] / time_data[k]

    # create performance per time dataframe
    performance_per_time_df = pd.DataFrame.from_dict(performance_per_time, orient='index')
    performance_per_time_df = performance_per_time_df.rename(columns={0: 'Performance Per Time: F1 Score / Training Time[sec]'})
    
    return performance_per_time_df

# %%
# compute algorithm efficiency - without a threshold
performance_per_time_no_threshold = compute_algorithm_efficiency(time_data, 0.0)

# %%
# compute algorithm efficiency - with a 0.55 threshold
performance_per_time_threshold = compute_algorithm_efficiency(time_data, 0.55)

# %%
# plot algorithm performance - without a threshold
performance_per_time_no_threshold.plot(kind='bar', grid=True, figsize=(16, 4), title='Algorithm Performance Without Threshold')

# %%
# plot algorithm performance - with threshold
performance_per_time_threshold.plot(kind='bar', grid=True, figsize=(16, 4), title='Algorithm Performance With Threshold')

# %%
# hyper-parameter tunning
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV

# %%
# define parameter search space
scale_c1 = 0.2
scale_c2 = 0.2

# define parameter discributions
param_space = {
    'c1': scipy.stats.expon(scale=scale_c1),
    'c2': scipy.stats.expon(scale=scale_c2)
}

# use the same metric for evaluation like we did for the previous algorithms
f1_scorer = make_scorer(metrics.flat_f1_score, average='weighted', labels=classes_without_o)

# search for the best parameters
rs = RandomizedSearchCV(model_crf, param_space, cv=3, n_jobs=-1, n_iter=1000, scoring=f1_scorer)

# %%
# %%time
# fit the model
rs.fit(x_train, y_train)
# Out:
# /home/andrei/work/repos/datascience/venv/lib/python3.7/site-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CPU times: user 1h 55min 2s, sys: 4.38 s, total: 1h 55min 6s
# Wall time: 3h 44min 3s
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=CRF(algorithm='lbfgs', all_possible_states=None,
#                                  all_possible_transitions=True, averaging=None,
#                                  c=None, c1=None, c2=None,
#                                  calibration_candidates=None,
#                                  calibration_eta=None,
#                                  calibration_max_trials=None,
#                                  calibration_rate=None,
#                                  calibration_samples=None, delta=None,
#                                  epsilon=None, error_sensitive=None, gamma=None,
#                                  keep_...
#                                         'c2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7ff403d13dd0>},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False,
#                    scoring=make_scorer(flat_f1_score, average=weighted, labels=['B-geo', 'I-art', 'B-eve', 'I-per', 'B-nat', 'B-tim', 'I-nat', 'I-gpe', 'B-gpe', 'I-org', 'B-org', 'I-eve', 'B-per', 'I-geo', 'I-tim', 'B-art']),
#                    verbose=0)

# %%
print('best params:', rs.best_params_)
print('best CV scores: ', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_/1000000))

model_crf_tuned = rs.best_estimator_
y_pred = model_crf_tuned.predict(x_test)

report = metrics.flat_classification_report(y_pred=y_pred, y_true=y_test, labels=classes_without_o, output_dict=True)

cr['crf_tuned'] = report['weighted avg']
# Out:
# best params: {'c1': 0.004212682251657764, 'c2': 0.141785900234215}
# best CV scores:  0.7207238078508665
# model size: 0.70M

# %%
# visualize parameter space
font = {'family': 'normal', 'size': 10}
plt.rc('font', **font)

def plot_parameters(x, y, c, title=''):
    fig = plt.figure()
    fig.set_size_inches(6,6)
    ax = plt.gca()
    ax.set_yscale('log')
    ax.set_xscale('log')
    ax.set_xlabel('C1')
    ax.set_xlabel('C2')
    ax.set_title(title)
    
    if len(x) == len(c):
        ax.scatter(x, y, c=c, s=15, alpha=0.9)
    else:
        plt.plot(x, y, marker='.', color='k', linestyle='none')

# %%
# plot search points without fitness score
x = [_ for _ in rs.cv_results_['param_c1']]
y = [_ for _ in rs.cv_results_['param_c2']]
c = [0.5 for _ in rs.cv_results_['mean_test_score']]

# plot parameters
plot_parameters(x, y, c, 'Randomized Hyperparameter Search CV Results')
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
# grid search
_x = np.arange(0, scale_c1, scale_c1 / 20)
_y = np.arange(0, scale_c2, scale_c2 / 20)

x, y = np.meshgrid(_x, _y)

x_ = np.hstack(x) # convert to 1-dimension array
y_ = np.hstack(y) # convert to 1-dimension array
c = [0.0 for _ in _x]

# plot parameters - grid format
plot_parameters(x_, y_, c=c, title='Grid Search CV')

# %%
_x = [_ for _ in rs.cv_results_['param_c1']]
_y = [_ for _ in rs.cv_results_['param_c2']]
_c = [_ for _ in rs.cv_results_['mean_test_score']]

# plot parameters - hypertuning
plot_parameters(_x, _y, _c, title="Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".format(min(_c), max(_c)))

# %%
# performance compare
# convert overall classification report to Pandas DataFrame
cr_df = pd.DataFrame.from_dict(cr, orient='index')

# compute % delta difference to CRF
cr_df_delta = pd.DataFrame(columns=['precision', 'recall', 'f1-score'])
cr_df_delta.loc['sgd'] = (cr_df.loc['sgd'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100
cr_df_delta.loc['nb'] = (cr_df.loc['nb'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100
cr_df_delta.loc['lr'] = (cr_df.loc['lr'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100
cr_df_delta.loc['svc'] = (cr_df.loc['svc'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100
cr_df_delta.loc['dt'] = (cr_df.loc['dt'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100
cr_df_delta.loc['crf'] = (cr_df.loc['crf'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100
cr_df_delta.loc['crf_tuned'] = (cr_df.loc['crf_tuned'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100

# %%
# plot absolute performance
cr_df_delta.plot(kind='bar', grid=True, figsize=(16, 4), title='Performance Delta to CRF Tuned [%]')

# add training time for CRF tuned
time_data['crf_tuned'] = 720

# %%
# compute efficiency - with a 0.55 threshold
performance_per_time_threshold = compute_algorithm_efficiency(time_data, 0.55)

# %%
# plot algorithm performance
performance_per_time_threshold.plot(kind='bar', grid=True, figsize=(16, 4), title='Algorithm Performance')

# %%
# learned transitions
def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.3f" % (label_from, label_to, weight))

# %%
from collections import Counter

print("Top likely transitions:")
print_transitions(Counter(model_crf_tuned.transition_features_).most_common(20))
# Out:
# Top likely transitions:
# I-org  -> I-org   5.297
# B-org  -> I-org   5.168
# B-geo  -> I-geo   4.793
# B-tim  -> I-tim   4.756
# B-per  -> I-per   4.718
# I-per  -> I-per   4.550
# I-tim  -> I-tim   4.329
# O      -> O       3.902
# B-gpe  -> I-gpe   3.748
# I-geo  -> I-geo   3.481
# B-art  -> I-art   3.447
# B-eve  -> I-eve   3.202
# I-art  -> I-art   3.156
# O      -> B-per   2.663
# I-gpe  -> I-gpe   2.563
# B-nat  -> I-nat   2.390
# I-eve  -> I-eve   2.225
# O      -> B-org   2.178
# B-org  -> B-art   2.022
# B-gpe  -> B-org   1.989

# %%
print("Top unlikely transitions:")
print_transitions(Counter(model_crf_tuned.transition_features_).most_common()[-20:])
# Out:
# Top unlikely transitions:
# B-gpe  -> I-org   -0.968
# B-gpe  -> I-geo   -0.991
# I-tim  -> B-tim   -0.993
# B-org  -> I-geo   -1.025
# O      -> I-gpe   -1.034
# B-org  -> I-per   -1.108
# B-geo  -> I-per   -1.111
# B-tim  -> B-gpe   -1.149
# B-geo  -> I-gpe   -1.164
# I-org  -> I-per   -1.216
# B-tim  -> B-tim   -1.234
# B-org  -> B-org   -1.326
# O      -> I-art   -1.368
# I-per  -> B-per   -1.512
# B-per  -> B-per   -1.751
# O      -> I-per   -1.769
# B-gpe  -> B-gpe   -2.047
# O      -> I-geo   -2.074
# O      -> I-org   -2.564
# O      -> I-tim   -2.660

# %%
# check state features
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.2f %-8s %s" % (weight, label, attr))

# %%
print("Top positive:")
print_state_features(Counter(model_crf_tuned.state_features_).most_common(20))
# Out:
# Top positive:
# 4.82 O        bias
# 4.28 B-tim    word[-2:]:0s
# 3.93 O        BOS
# 3.89 B-tim    word[-2:]:ay
# 3.86 B-tim    word[-3:]:day
# 2.84 B-per    +1:word.lower():administration
# 2.83 B-gpe    word.istitle()
# 2.75 O        word.lower():israeli-palestinian
# 2.71 B-per    BOS
# 2.68 B-org    word.lower():al-qaida
# 2.56 B-tim    word[-3:]:ber
# 2.56 B-tim    -1:word.lower():year
# 2.54 B-org    word.lower():hamas
# 2.53 B-tim    +1:word.lower():year
# 2.36 I-tim    word[-2:]:ay
# 2.32 B-gpe    -1:word.lower():recognize
# 2.31 B-tim    word.lower():by-election
# 2.29 B-geo    word.lower():second-in-command
# 2.26 O        -1:word.lower():prime
# 2.16 B-org    word[-3:]:ban

# %%
print("Top negative:")
print_state_features(Counter(model_crf_tuned.state_features_).most_common()[-20:])
# Out:
# Top negative:
# -1.35 O        -1:word.lower():first
# -1.38 O        +1:word.lower():officials
# -1.38 O        -1:word.lower():before
# -1.39 O        +1:word.lower():saturday
# -1.47 O        word[-2:]:ni
# -1.50 I-per    +1:postag[:2]:NN
# -1.59 B-geo    word[-2:]:er
# -1.63 O        +1:word.lower():term
# -1.70 B-art    -1:word.istitle()
# -1.73 O        word.lower():later
# -1.83 O        +1:word.lower():year
# -1.84 O        +1:word.lower():years
# -1.99 O        -1:word.lower():parliamentary
# -2.16 O        postag[:2]:NN
# -2.19 O        -1:word.lower():year
# -2.45 O        +1:word.lower():months
# -2.60 O        word.isupper()
# -2.69 O        word.isdigit()
# -3.76 O        word.istitle()
# -3.78 O        postag:NNP

# %%
import eli5

# inspect model weights
eli5.show_weights(model_crf, top=10)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-art</th>
#
#                 <th>I-art</th>
#
#                 <th>B-eve</th>
#
#                 <th>I-eve</th>
#
#                 <th>B-geo</th>
#
#                 <th>I-geo</th>
#
#                 <th>B-gpe</th>
#
#                 <th>I-gpe</th>
#
#                 <th>B-nat</th>
#
#                 <th>I-nat</th>
#
#                 <th>B-org</th>
#
#                 <th>I-org</th>
#
#                 <th>B-per</th>
#
#                 <th>I-per</th>
#
#                 <th>B-tim</th>
#
#                 <th>I-tim</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 82.80%)" title="O &rArr; O">
#                             3.144
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 93.78%)" title="O &rArr; B-art">
#                             0.736
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.25%)" title="O &rArr; I-art">
#                             -1.007
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 93.93%)" title="O &rArr; B-eve">
#                             0.71
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.01%)" title="O &rArr; I-eve">
#                             -0.696
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 90.62%)" title="O &rArr; B-geo">
#                             1.323
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.20%)" title="O &rArr; I-geo">
#                             -1.408
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.82%)" title="O &rArr; B-gpe">
#                             1.088
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.74%)" title="O &rArr; I-gpe">
#                             -0.742
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 97.19%)" title="O &rArr; B-nat">
#                             0.236
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.74%)" title="O &rArr; I-nat">
#                             -0.578
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 89.34%)" title="O &rArr; B-org">
#                             1.588
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 88.09%)" title="O &rArr; I-org">
#                             -1.859
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.83%)" title="O &rArr; B-per">
#                             1.697
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.31%)" title="O &rArr; I-per">
#                             -1.186
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 89.39%)" title="O &rArr; B-tim">
#                             1.578
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 87.81%)" title="O &rArr; I-tim">
#                             -1.923
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-art</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.74%)" title="B-art &rArr; O">
#                             -0.429
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.32%)" title="B-art &rArr; B-art">
#                             -0.031
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 85.75%)" title="B-art &rArr; I-art">
#                             2.403
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.43%)" title="B-art &rArr; B-eve">
#                             -0.024
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.09%)" title="B-art &rArr; I-eve">
#                             -0.136
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.26%)" title="B-art &rArr; B-geo">
#                             -0.119
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.37%)" title="B-art &rArr; I-geo">
#                             -0.216
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.12%)" title="B-art &rArr; B-gpe">
#                             -0.133
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.93%)" title="B-art &rArr; I-gpe">
#                             -0.153
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.48%)" title="B-art &rArr; B-nat">
#                             -0.021
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.67%)" title="B-art &rArr; I-nat">
#                             -0.081
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.74%)" title="B-art &rArr; B-org">
#                             -0.173
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.11%)" title="B-art &rArr; I-org">
#                             -0.246
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.88%)" title="B-art &rArr; B-per">
#                             -0.274
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.35%)" title="B-art &rArr; I-per">
#                             -0.343
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 98.69%)" title="B-art &rArr; B-tim">
#                             0.08
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.79%)" title="B-art &rArr; I-tim">
#                             -0.168
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-art</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.73%)" title="I-art &rArr; O">
#                             -0.429
#                         </td>

# %%
# check only a subset of tags
eli5.show_weights(model_crf, top=10, targets=['B-geo', 'I-tim', 'B-per'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>B-geo</th>
#
#                 <th>I-tim</th>
#
#                 <th>B-per</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>B-geo</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.84%)" title="B-geo &rArr; B-geo">
#                             -0.33
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.97%)" title="B-geo &rArr; I-tim">
#                             -0.561
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.66%)" title="B-geo &rArr; B-per">
#                             -0.472
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-tim</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.90%)" title="I-tim &rArr; B-geo">
#                             0.324
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="I-tim &rArr; I-tim">
#                             3.113
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.03%)" title="I-tim &rArr; B-per">
#                             -0.204
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-per</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.58%)" title="B-per &rArr; B-geo">
#                             -0.249
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.24%)" title="B-per &rArr; I-tim">
#                             -0.286
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.11%)" title="B-per &rArr; B-per">
#                             -0.977
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-geo
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-tim
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-per
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.602
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:word.lower():in
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.322
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         postag:NNP
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.017
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.istitle()
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         +1:word.lower():province
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.896
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:rn
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.837
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:word.lower():southern
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 87.44%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 772 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.29%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 117 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.851
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:postag:NNP
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.854
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:word.istitle()
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.912
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:postag[:2]:NN
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.43%); border: none;">
#     <td st

# %%
# check only some of the features for all tags
eli5.show_weights(model_crf, top=10, feature_re='^word\.is', horizontal_layout=False, show=['targets'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=O
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 86.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.607
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isupper()
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.655
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isdigit()
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.924
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.istitle()
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=B-art
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.083
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isupper()
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.092
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isdigit()
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.093
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.istitle()
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=I-art
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.309
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isdigit()
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.038
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.istitle()
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.138
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isupper()
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=B-eve
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.238
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isdigit()
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.136
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.isupper()
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.002
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.istitle()
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %%
# fix strange character
raw_data.loc[1786].Word = 'is'

# split raw data into train and test
x_train, x_test, y_train, y_test = train_test_split(raw_data[['Word', 'POS']], raw_data['Tag'], test_size=0.2, random_state=3)

# create train data by adding "y_train" column
train_data = x_train.join(y_train)

# create test data by adding "y_test" column
test_data = x_test.join(y_test)

# select only useful columns: Word & Tag
train_data = train_data[['Word', 'POS', 'Tag']]
test_data = test_data[['Word', 'POS', 'Tag']]

# save train & test data to csv files
train_data.to_csv('train_data.iob', sep='\t', index=False, header=False)
test_data.to_csv('test_data.iob', sep='\t', index=False, header=False)

# %%
import subprocess

# method for running shell commands
def run_command(cmd):
    return subprocess.run(cmd, capture_output=True, encoding='utf-8', shell='True')

# %%
# convert train & test data from IOB format to JSON format
convert_train_data = 'python -m spacy convert -c iob train_data.iob . -s'
convert_test_data = 'python -m spacy convert -c iob test_data.iob . -s'

# run commands
p1 = run_command(convert_train_data)
p2 = run_command(convert_test_data)

print(p1)
print(p2)
# Out:
# CompletedProcess(args='python -m spacy convert -c iob train_data.iob . -s', returncode=0, stdout='\x1bℹ Auto-detected token-per-line NER format\x1b\n\x1bℹ Grouping every 1 sentences into a document.\x1b\n\x1b⚠ To generate better training data, you may want to group sentences\ninto documents with `-n 10`.\x1b\n\x1bℹ Segmenting sentences with sentencizer. (Use `-b model` for improved\nparser-based sentence segmentation.)\x1b\n\x1b✔ Generated output file (1004 documents): train_data.json\x1b\n', stderr='')
# CompletedProcess(args='python -m spacy convert -c iob test_data.iob . -s', returncode=0, stdout='\x1bℹ Auto-detected token-per-line NER format\x1b\n\x1bℹ Grouping every 1 sentences into a document.\x1b\n\x1b⚠ To generate better training data, you may want to group sentences\ninto documents with `-n 10`.\x1b\n\x1bℹ Segmenting sentences with sentencizer. (Use `-b model` for improved\nparser-based sentence segmentation.)\x1b\n\x1b✔ Generated output file (283 documents): test_data.json\x1b\n', stderr='')

# %%
# %%time
train_cmd = 'python -m spacy train en . train_data.json test_data.json -p ner -n 100'
p3 = run_command(train_cmd)

print(p3)
# Out:
# CompletedProcess(args='python -m spacy train en . train_data.json test_data.json -p ner -n 100', returncode=1, stdout="\x1b⚠ Output directory is not empty\x1b\nThis can lead to unintended side effects when saving the model. Please use an\nempty directory or a different path instead. If the specified output path\ndoesn't exist, the directory will be created for you.\nTraining pipeline: ['ner']\nStarting with blank model 'en'\nCounting training words (limit=0)\n\nItn  NER Loss   NER P   NER R   NER F   Token %  CPU WPS\n---  ---------  ------  ------  ------  -------  -------\n  1   4527.209  40.745  39.282  40.000  100.000    36264\n  2   2769.158  57.474  55.668  56.556  100.000    37591\n  3   2120.626  63.584  62.514  63.045  100.000    36966\n  4   1650.859  65.632  64.085  64.850  100.000    37602\n  5   1362.884  67.890  66.442  67.158  100.000    36949\n  6   1133.197  67.800  67.116  67.456  100.000    38266\n  7    911.518  67.431  65.993  66.704  100.000    37702\n  8    746.202  67.705  65.881  66.780  100.000    38057\n  9    624.906  67.471  65.881  66.667  100.000    38178\n 10    523.815  67.434  65.769  66.591  100.000    38100\n 11    455.960  67.894  66.218  67.045  100.000    38386\n 12    435.778  68.083  66.554  67.310  100.000    38522\n 13    354.274  67.927  66.554  67.234  100.000    38226\n 14    339.924  67.886  66.667  67.271  100.000    38285\n 15    246.343  67.698  66.330  67.007  100.000    38157\n 16    265.112  67.162  65.881  66.516  100.000    38218\n 17    267.875  67.468  66.105  66.780  100.000    38109\n 18    196.892  67.429  66.218  66.818  100.000    37980\n 19    237.566  67.123  65.993  66.553  100.000    37382\n 20    201.371  67.275  66.218  66.742  100.000    37873\n 21    203.046  67.122  66.218  66.667  100.000    37327\n 22    178.693  67.084  66.105  66.591  100.000    38184\n 23    190.394  66.819  65.769  66.290  100.000    37491\n 24    171.063  67.237  66.105  66.667  100.000    38324\n 25    168.802  67.009  65.881  66.440  100.000    38098\n 26    140.764  67.087  65.657  66.364  100.000    38231\n 27    133.908  67.281  65.544  66.401  100.000    38267\n 28    149.572  67.474  65.657  66.553  100.000    38376\n 29    114.264  67.589  65.769  66.667  100.000    38086\n 30    148.695  67.857  66.105  66.970  100.000    38049\n 31    110.054  68.097  65.881  66.971  100.000    37366\n 32     98.495  68.329  66.105  67.199  100.000    38063\n 33     95.552  68.634  66.554  67.578  100.000    37332\n 34    105.315  68.445  66.218  67.313  100.000    38032\n 35     95.338  68.366  66.218  67.275  100.000    37486\n 36     92.131  68.482  66.330  67.389  100.000    37773\n 37     77.488  68.293  65.993  67.123  100.000    36989\n 38     91.928  68.250  66.105  67.161  100.000    37982\n 39     83.267  68.324  66.330  67.312  100.000    37614\n 40    101.630  67.824  65.769  66.781  100.000    38183\n 41     95.599  67.787  65.657  66.705  100.000    37526\n 42     72.994  68.056  65.993  67.009  100.000    37779\n 43     90.081  68.329  66.105  67.199  100.000    37244\n 44     87.933  68.250  66.105  67.161  100.000    37719\n 45     71.590  68.092  66.105  67.084  100.000    36989\n 46     78.095  68.324  66.330  67.312  100.000    38148\n 47     87.553  67.898  65.993  66.932  100.000    37521\n 48     85.577  67.898  65.993  66.932  100.000    38184\n 49     69.921  68.046  66.442  67.235  100.000    38196\n 50     82.317  67.738  66.218  66.969  100.000    38069\n 51     64.669  67.849  66.554  67.195  100.000    38194\n 52     58.998  67.963  66.667  67.309  100.000    38119\n 53     66.737  67.963  66.667  67.309  100.000    37762\n 54     58.387  68.119  66.667  67.385  100.000    37896\n 55     64.699  68.427  66.891  67.650  100.000    37714\n 56     70.386  68.427  66.891  67.650  100.000    38012\n 57     82.833  68.391  66.779  67.575  100.000    37792\n 58     77.351  68.307  67.003  67.649  100.000    38162\n 59     93.689  68.650  67.340  67.989  100.000    378 ...
# CPU times: user 120 ms, sys: 39.6 ms, total: 160 ms
# Wall time: 4min 22s

# %%
# read performance scores
with open('model-final/meta.json') as f:
    score = json.loads(f.read())
    
# store performance scores
cr['spacy'] = {'precision': score['accuracy']['ents_p'] / 100, 
               'recall': score['accuracy']['ents_r'] / 100,
               'f1-score': score['accuracy']['ents_f'] / 100}

# convert overall classification report to Pandas
cr_df = pd.DataFrame.from_dict(cr, orient='index')

# %%
cr_df['precision'].plot(kind='bar', grid=True, figsize=(16,4), title='Precision')

# %%
cr_df['recall'].plot(kind='bar', grid=True, figsize=(16,4), title='Recall')

# %%
cr_df['f1-score'].plot(kind='bar', grid=True, figsize=(16,4), title='F1 Score')

# %%
# compute performance delta in %
cr_df_delta.loc['spacy'] = (cr_df.loc['spacy'] - cr_df.loc['crf_tuned']) / cr_df.loc['crf_tuned'] * 100

# %%
# plot absolute performance
cr_df_delta.plot(kind='bar', grid=True, figsize=(16,4), title='Performance Delta to CRF Tuned [%]')

# %%
# add training time for CRF tuned
time_data['spacy'] = 262 # seconds

# %%
# compute efficiency with a 0.55 threshold
performance_per_time_threshold = compute_algorithm_efficiency(time_data, 0.55)

# %%
# plot algorithm performance
performance_per_time_threshold.plot(kind='bar', grid=True, figsize=(16,4), title='Algorithm Performance')

# %%
# load trained model from 'model-final' folder
nlp2 = spacy.load('model-final')

# %%
sentence_idx = 455

# retrieve sentence text
sentence_txt = ' '.join([it[0] for it in sentences[sentence_idx]])

print('Sentence text: ', sentence_txt)

print(sentences[sentence_idx])
# Out:
# Sentence text:  The FAO 's estimate includes damage to fishing industries in Indonesia , Maldives , Somalia , Sri Lanka and Thailand .
# [('The', 'DT', 'O'), ('FAO', 'NNP', 'B-org'), ("'s", 'POS', 'O'), ('estimate', 'NN', 'O'), ('includes', 'VBZ', 'O'), ('damage', 'NN', 'O'), ('to', 'TO', 'O'), ('fishing', 'NN', 'O'), ('industries', 'NNS', 'O'), ('in', 'IN', 'O'), ('Indonesia', 'NNP', 'B-geo'), (',', ',', 'O'), ('Maldives', 'NNP', 'B-geo'), (',', ',', 'O'), ('Somalia', 'NNP', 'B-geo'), (',', ',', 'O'), ('Sri', 'NNP', 'B-geo'), ('Lanka', 'NNP', 'I-geo'), ('and', 'CC', 'O'), ('Thailand', 'NNP', 'B-geo'), ('.', '.', 'O')]

# %%
# create input and output training data
x = [sent2features(s) for s in [sentences[sentence_idx]]]

# %%
# run CRF model
crf_tokens = model_crf_tuned.predict(x)

# %%
# print NER tokens for CRF
print('CRF NER: ', [(w[0], t) for w,t in zip(sentences[sentence_idx], crf_tokens[0])])
# Out:
# CRF NER:  [('The', 'O'), ('FAO', 'B-org'), ("'s", 'O'), ('estimate', 'O'), ('includes', 'O'), ('damage', 'O'), ('to', 'O'), ('fishing', 'O'), ('industries', 'O'), ('in', 'O'), ('Indonesia', 'B-geo'), (',', 'O'), ('Maldives', 'B-geo'), (',', 'O'), ('Somalia', 'B-geo'), (',', 'O'), ('Sri', 'B-geo'), ('Lanka', 'I-geo'), ('and', 'O'), ('Thailand', 'B-geo'), ('.', 'O')]

# %%
# run SpaCy
doc = model_spacy(sentence_txt)

# %%
# print NER tokens for SpaCy
print('SpaCy NER: ', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# SpaCy NER:  [('The', '', 2), ('FAO', 'org', 3), ("'s", '', 2), ('estimate', '', 2), ('includes', '', 2), ('damage', '', 2), ('to', '', 2), ('fishing', '', 2), ('industries', '', 2), ('in', '', 2), ('Indonesia', 'geo', 3), (',', '', 2), ('Maldives', 'per', 3), (',', '', 2), ('Somalia', 'geo', 3), (',', '', 2), ('Sri', 'per', 3), ('Lanka', 'gpe', 3), ('and', '', 2), ('Thailand', 'geo', 3), ('.', '', 2)]

# %%
from spacy import displacy

displacy.serve(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FAO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">org</span>
# </mark>
#  's estimate includes damage to fishing industries in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indonesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">geo</span>
# </mark>
#  ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maldives
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">per</span>
# </mark>
#  ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Somalia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">geo</span>
# </mark>
#  ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">per</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lanka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">gpe</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thailand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">geo</span>
# </mark>
#  .</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
# ----------------------------------------
# Exception happened during processing of request from ('185.151.243.193', 54534)
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.7/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.7/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.7/socketserver.py", line 720, in __init__
#     self.handle()
#   File "/usr/lib/python3.7/wsgiref/simple_server.py", line 118, in handle
#     self.raw_requestline = self.rfile.readline(65537)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
# 185.202.2.149 - - [25/May/2020 23:41:04] code 400, message Bad HTTP/0.9 request type ('\x03\x00\x00/*à\x00\x00\x00\x00\x00Cookie:')
# 185.202.2.149 - - [25/May/2020 23:41:04] "/*àCookie: mstshash=Administr" 400 -
# ----------------------------------------
# Exception happened during processing of request from ('185.151.243.192', 26365)
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.7/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.7/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.7/socketserver.py", line 720, in __init__
#     self.handle()
#   File "/usr/lib/python3.7/wsgiref/simple_server.py", line 118, in handle
#     self.raw_requestline = self.rfile.readline(65537)
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
# 71.6.199.23 - - [26/May/2020 03:25:17] "GET / HTTP/1.1" 200 2790
# 71.6.199.23 - - [26/May/2020 03:25:18] "GET /favicon.ico HTTP/1.1" 200 2790
# Shutting down server on port 5000.
